# %% [markdown]
# ## <font color = forestgreen> 17 DEC  [ dataset/titanic.csv file:-]
# #### <font color = darkorange>            DATA ANALYSIS

# %% [markdown]
# # <font color = magenta > 2nd Assignments For titanic.csv :-

# %% [markdown]
# dataset/titanic.csv file:-
#
# 1. How to find out total no. of records & columns?
#
# 2. How to find out all missing values count in all columns?
#
# 3. How to show all missing age records?
#
# 4. How to show all missing Embarked records?
#
# 5. show total count survived or not survived passenger?
#
# 6. How to find out total count survived male & female passenger?
#
# 7. How to find all passenger count which Fare=0 ?
#
# 8. How many survived passenger count which Fare=0 ?
#
# 9. Show maximum fare only 3 passenger list ?
#
# 10. Only show 3 columns with maximum fare 3 passenger list ?
#
# 11. All missing Embarked data rows dropped ?
#
# 12. All missing Age values replace with NaN to -1 ?
#
# 13. show all records which Fare b/w 0 to <100 ?
#
# 14. show all minimum Fare=0 & maximum Fare records b/w 0 to <100 ?

# %% [markdown]
# # <font color = magenta > -----------------------------------------------------------------------------------

# %%
from IPython.display import Image,display
display(Image('titanic.png'))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset/titanic.csv')   # automatic create dataframe from csv file

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 titanic.head()
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# # 1.How to find out total no. of records & columns?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How to find out all missing values count in all columns?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # How to show titanic all columns which have missing_data ?

# %%
# Identify rows with any missing values using .loc
missing_columns = titanic.loc[titanic.isnull().any(axis=1)]
missing_columns
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 31            32         1       1
# 32            33         1       3
# ...

# %% [markdown]
# # same output by without using .loc

# %%
# Identify rows with any missing values using .loc
missing_columns = df[df.isnull().any(axis=1)]
missing_columns
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # How to show titanic all top 10 columns which have missing_data ?

# %%
# Identify rows with any missing values using .loc
missing_top_columns = titanic[titanic.isnull().any(axis=1)].head(10)
missing_top_columns
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# # How to show titanic bottom 10 columns which have missing_data ?

# %%
missing_bottom_columns=titanic[titanic.isnull().any(axis=1)].tail(10)
missing_bottom_columns
# Out:
#      PassengerId  Survived  Pclass  \
# 878          879         0       3
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 878                            Laleff, Mr. Kristo    male   NaN      0      0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 881                            Markun, Mr. Johann    male  33.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 884                        Sutehall, Mr. Henry Jr    male  25.0      0      0
# ...

# %% [markdown]
# # same result with [ using .loc attributes ]

# %% [markdown]
# # for bottom

# %%
missing_bottom_columns=titanic.loc[titanic.isnull().any(axis=1)].tail(10)
missing_bottom_columns
# Out:
#      PassengerId  Survived  Pclass  \
# 878          879         0       3
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 878                            Laleff, Mr. Kristo    male   NaN      0      0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 881                            Markun, Mr. Johann    male  33.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 884                        Sutehall, Mr. Henry Jr    male  25.0      0      0
# ...

# %% [markdown]
# # for top

# %%
missing_head_columns=titanic.loc[titanic.isnull().any(axis=1)].head(10)
missing_head_columns
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# # 3.How to show all missing age records?

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # 4.How to show all missing Embarked records?

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# # 5.Show total count survived or not survived passenger?

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df[df

# %% [markdown]
# # 6. How to find out total count survived male & female passenger?

# %%
df[df.Survived==1].Sex.value_counts()    # [=1] survived male & female _count
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
df[df.Survived==0].Sex.value_counts()    # [=0] not survived male & female_count
# Out:
# Sex
# male      468
# female     81
# Name: count, dtype: int64

# %% [markdown]
# # 7. How to find all passenger count which Fare=0 ?

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df[df.Fare==0].Survived.value_counts()
# Out:
# Survived
# 0    14
# 1     1
# Name: count, dtype: int64

# %%
df[(df.Fare==0)&(df.Survived==0)].Sex.value_counts()    # not survived passenger_count which Fare=0
# Out:
# Sex
# male    14
# Name: count, dtype: int64

# %% [markdown]
# # 8. How many survived passenger count which Fare=0 ?

# %%
df[(df.Fare==0)&(df.Survived==1)].shape   
# Or df[(df.Fare==0)&(df.Survived==1)].Sex.value_counts()
# Out:
# (1, 12)

# %% [markdown]
# # 9. Show maximum fare only 3 passenger list ?

# %%
# Sorting the DataFrame by 'Fare' in descending order and selecting the top 3 rod
df.sort_values(by='Fare', ascending=False).head(3)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 10. Only show 3 columns with maximum fare 3 passenger list ?

# %%
m=df.sort_values(by='Fare',ascending=False).head(3)
m
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C

# %%
m=df.sort_values(by='Fare',ascending=False).head(3)
m.loc[:,['Name','Age','Fare']]
# Out:
#                                    Name   Age      Fare
# 258                    Ward, Miss. Anna  35.0  512.3292
# 737              Lesurer, Mr. Gustave J  35.0  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0  512.3292

# %%
m=df.sort_values('Fare',ascending=False).index.tolist()[:3]
m
# Out:
# [258, 737, 679]

# %%
# Or 
m=df.sort_values('Fare',ascending=False).index.tolist()[:3]
df.loc[m,['Name','Sex','Fare']]
# Out:
#                                    Name     Sex      Fare
# 258                    Ward, Miss. Anna  female  512.3292
# 737              Lesurer, Mr. Gustave J    male  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez    male  512.3292

# %%
j=df[df.Embarked.isnull()]  # how show all missing Embarked records
j
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# # 11. All missing Embarked data rows dropped ?

# %% [markdown]
# # <font color = green >For solve missing records 2 methods in pandas :- 1. dropna    2. fillna

# %%
e=df[df.Embarked.isnull()]
e
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
j.dropna(axis='columns')   # All missing Embarked_data dropped
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin
# 61   female  38.0      0      0  113572  80.0   B28
# 829  female  62.0      0      0  113572  80.0   B28

# %% [markdown]
# # 12. All missing Age values replace with NaN to -1 ?

# %%
j=df[df.Age.isnull()]  # how to show all age missing records
j
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
f=j.fillna(-1)
f
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# # How to create csv file in pandas to doing extarnal_task on it

# %%
j=df[df.Age.isnull()]  # how to show all age missing records
j
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
j.shape
# Out:
# (177, 12)

# %% [markdown]
# # Note : For Creating csv file index = False giving is mandatory otherwise index of j file
# # will write into new csv file

# %%
j.to_csv('dataset/new.csv',index=False)   # For create csv_file

# %%
j
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
f=j.fillna(-1)  
f
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# # 13. show all records which Fare b/w 0 to <100 ?

# %%
m=df[(df.Fare<100)]
m
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df.Fare<100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 14. show all minimum Fare=0 & maximum Fare records b/w  <100 ?

# %%
m=df[(df.Fare<100)]

# %%
m
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
h=m[(m.Fare==np.max(m.Fare))|(m.Fare==np.min(m.Fare))]
h
# Out:
#      PassengerId  Survived  Pclass  \
# 179          180         0       3
# 263          264         0       1
# 271          272         1       3
# 277          278         0       2
# 302          303         0       3
# 413          414         0       2
# 466          467         0       2
# 481          482         0       2
# 520          521         1       1
# 597          598         0       3
# 633          634         0       1
# 674          675         0       2
# 732          733         0       2
# 806          807         0       1
# 815          816         0       1
# 820          821         1       1
# 822          823         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 179                                Leonard, Mr. Lionel    male  36.0      0
# 263                              Harrison, Mr. William    male  40.0      0
# 271                       Tornquist, Mr. William Henry    male  25.0      0
# ...

# %%
h.shape
# Out:
# (17, 12)

# %%
a=df.sort_values(by='Age',ascending=False)[:5]
a
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
s=titanic.sort_values(by='Survived',ascending=False)[:4]
s
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 319          320         1       1
# 334          335         1       1
# 330          331         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female   NaN      1
# 330                                 McCoy, Miss. Agnes  female   NaN      2
#
#      Parch    Ticket      Fare Cabin Embarked
# 445      2     33638   81.8583   A34        S
# 319      1     16966  134.5000   E34        C
# 334      0  PC 17611  133.6500   NaN        S
# 330      0    367226   23.2500   NaN        Q

# %%
titanic.Age.isnull().sum()
# Out:
# 177
